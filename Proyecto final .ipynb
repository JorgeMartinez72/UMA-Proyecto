# %%
def Calculo_montos(interes, tipo_interes, capital_inicial, tiempo):
    interes = interes / 100
    if tipo_interes == "Compuesto":
        tipo_interes1 = input("¿Tu interes en Nominal?")
        if tipo_interes1 == "si" or tipo_interes1 == "Si":
            tipo_interes_1 = input('¿La efectividad de tu tasa es anual?')
            if tipo_interes_1 == "no" or tipo_interes_1 == "No":
                tipo_interes_nom = input("¿Como es su efectividad?")
                if tipo_interes_nom == "Trimestral" or tipo_interes_nom == "trimestral":
                    monto = capital_inicial * ( 1 + (interes*tiempo) )
                    ganancia = monto - capital_inicial
                    interes_efectivo = (((1 + interes) ** (1/4)) - 1)
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif tipo_interes_nom == "Mensual" or tipo_interes_nom == "mensual":
                    monto = capital_inicial * ( 1 + (interes*tiempo) )
                    ganancia = monto - capital_inicial
                    interes_efectivo = (((1 + interes) ** (1/12)) - 1) 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif tipo_interes_nom == "Diaria" or tipo_interes_nom == "diaria":
                    monto = capital_inicial * ( 1 + (interes*tiempo) )
                    ganancia = monto - capital_inicial
                    interes_efectivo = (((1 + interes) ** (1/360)) - 1) 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif tipo_interes_nom == "Bimestral" or tipo_interes_nom == "Bimestral":
                    monto = capital_inicial * ( 1 + (interes*tiempo) )
                    ganancia = monto - capital_inicial
                    interes_efectivo = (((1 + interes) ** (1/6)) - 1) 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif tipo_interes_nom == "Semestral" or tipo_interes_nom == "semestrl":
                    monto = capital_inicial * ( 1 + (interes*tiempo) )
                    ganancia = monto - capital_inicial
                    interes_efectivo = (((1 + interes) ** (1/2)) - 1) 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif tipo_interes_nom == "Anual" or tipo_interes_nom == "anual":
                    monto = capital_inicial * ( 1 + (interes*tiempo) )
                    ganancia = monto - capital_inicial
                    interes_efectivo = (capital_inicial * ((1 + interes) ** tiempo))
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
            elif tipo_interes_1 == "si" or tipo_interes_1 == "Si":
                monto = capital_inicial * ((1 + (interes)) ** tiempo)
                ganancia = monto - capital_inicial
                return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
            
                
            
        elif tipo_interes1 == "no" or tipo_interes1 == "No":
            monto = capital_inicial * ( 1 + (interes*tiempo))
            ganancia = monto - capital_inicial
            return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
        else: 
            print("Opcion Invalida-")
            print("Escibre, Opciones para moestar las opciones disponibles.")
            opcion = input("")
            if opcion == "Opciones":
                print("Opciones: Si,  No")
                print("saliendo del probgrama")
            else: 
                print("saliendo del programa...")
    elif tipo_interes == "Simple":
        monto = capital_inicial * ( 1 + (interes*tiempo) )
        ganancia = monto - capital_inicial     
        return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"

# %%
Calculo_montos(4 ,"Compuesto",10000,13)
# Out:
# ¿Tu interes en Nominal?asd
# Opcion Invalida-
# Escibre, Opciones para moestar las opciones disponibles.
#
# saliendo del programa...

# %%
def calculo_montos(interes, tipo_interes, capital_inicial, tiempo):
    interes = interes / 100
    tipo_interes = tipo_interes.lower()
    tipo_interes = tipo_interes.strip()
    if tipo_interes == "compuesto":
        nip = input("¿Tu interes es efectivo por periodo? ")
        nip = nip.lower()
        nio = nip.strip()
        if nip == "si":
            monto = (capital_inicial * ((1 + interes) ** tiempo))
            ganancia = monto - capital_inicial
            return f"El monto total es {monto}, la ganancia es de {ganancia}. "
        elif nip == "no":
            tasa_nominal = input("¿Cual es la efectividad de la tasa? ")
            tasa_nominal == tasa_nominal.lower()
            tasa_nominal == tasa_nominal.strip()
            conversion = input("¿Cual es su conversion? ")
            if tasa_nominal == "anual":
                conversion == conversion.lower()
                conversion == conversion.strip()
                if conversion == "trimestral":
                    interes_efectivo = (((1 + interes) ** (1/4)) - 1)
                    monto = (capital_inicial * ((1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion  == "mensual":
                    interes_efectivo = (((1 + interes) ** (1/12)) - 1) 
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion == "diaria":
                    interes_efectivo = (((1 + interes) ** (1/360)) - 1)                    
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion == "bimestral":
                    interes_efectivo = (((1 + interes) ** (1/6)) - 1)    
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion =="semestral":
                    interes_efectivo = (((1 + interes) ** (1/2)) - 1)  
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                else:
                    print(f"Opcion invalida. \nSaliendo del programa...")
            elif tasa_nominal == "bianual":
                conversion == conversion.lower()
                conversion == conversion.strip()
                if conversion == "trimestral":
                    interes_efectivo = (((1 + interes) ** (1/8)) - 1)
                    monto = (capital_inicial * ((1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion  == "mensual":
                    interes_efectivo = (((1 + interes) ** (1/24)) - 1) 
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion == "diaria":
                    interes_efectivo = (((1 + interes) ** (1/720)) - 1)                    
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion == "bimestral":
                    interes_efectivo = (((1 + interes) ** (1/12)) - 1)    
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion =="semestral":
                    interes_efectivo = (((1 + interes) ** (1/4)) - 1)  
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                else:
                    print(f"Opcion invalida. \nSaliendo del programa...")
            elif tasa_nominal == "quinquenal":
                conversion == conversion.lower()
                conversion == conversion.strip()
                if conversion == "trimestral":
                    interes_efectivo = (((1 + interes) ** (1/20)) - 1)
                    monto = (capital_inicial * ((1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion  == "mensual":
                    interes_efectivo = (((1 + interes) ** (1/60)) - 1) 
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion == "diaria":
                    interes_efectivo = (((1 + interes) ** (1/1800)) - 1)                    
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial 
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion == "bimestral":
                    interes_efectivo = (((1 + interes) ** (1/30)) - 1)    
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                elif conversion =="semestral":
                    interes_efectivo = (((1 + interes) ** (1/10)) - 1)  
                    monto = (capital_inicial * (( 1 + interes_efectivo) ** tiempo))
                    ganancia = monto - capital_inicial
                    return f"El monto final es: {monto}, tu ganancia es de: {ganancia}"
                else:
                    print(f"Opcion invalida. \nSaliendo del programa...")
        else:
             print(f"Opcion invalida. \nSaliendo del programa...")
                
    elif tipo_interes == "simple":
        pass
    else:
        print(f"El tipo de interes {tipo_interes} no se reconoce. \nSaliendo del programa...")

# %%
calculo_montos(4 ,"compuesto",10000,13)
# Out:
# ¿Tu interes es efectivo por periodo? si
# 'El monto total es 16650.73507310389, la ganancia es de 6650.73507310389. '
